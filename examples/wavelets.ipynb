# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import healpy as hp
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2
from pynilc import NeedletTransform, HealpixDUCC

# %%
bandcenters = np.array([0, 100, 200, 350, 500, 750, 1000, 1350, 1700, 2000])

# %%
needlet_bands = NeedletTransform.CosineNeedlet(bandcenters)
nbands = needlet_bands.shape[0]
nlmax = needlet_bands.shape[1] - 1

# %%
for i in range(nbands):
     plt.plot(np.arange(nlmax + 1), needlet_bands[i, :], label=f'Band {i + 1}', linewidth=2)

# %%
needlet_bands = NeedletTransform.TaperedTopHat(bandcenters,100,10)
nbands = needlet_bands.shape[0]
nlmax = needlet_bands.shape[1] - 1

# %%
for i in range(nbands):
     plt.plot(np.arange(nlmax + 1), needlet_bands[i, :], label=f'Band {i + 1}', linewidth=2)

# %%
needlet_bands = NeedletTransform.GaussianNeedlets(np.array([600., 300., 120., 60., 30., 15., 10., 7.5, 5.]),2000)
nbands = needlet_bands.shape[0]
nlmax = needlet_bands.shape[1] - 1
